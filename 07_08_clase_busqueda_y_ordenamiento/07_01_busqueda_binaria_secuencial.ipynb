# %% [markdown]
# <a href="https://colab.research.google.com/github/IEXE-Tec/analisis_de_algoritmos/blob/main/07_08_clase_busqueda_y_ordenamiento/07_01_busqueda_binaria_secuencial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Busqueda Binaria Binaria

# %% [markdown]
# Escribe de manera secuencial la funcion de Busqueda Binaria Recursiva `sec_bin_search` del notebook de la clase.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Tu algoritmo

# %%
def sec_bin_search(arr=[],ele):
  # TODO
  
  return
